# %% [markdown]
# # Project 3
# ## Author: Firasath

# %% [markdown]
# ## Introduction
# ============
#
# ### Understanding Car Acceptability: A Data-Driven Approach
# -------------------------------------------------------
#
# In the rapidly evolving automotive industry, understanding what makes a car acceptable to consumers is crucial for both manufacturers and buyers. The myriad of factors ranging from safety, cost, to comfort play a significant role in shaping a vehicle's desirability. This report delves into an extensive dataset of cars, encompassing various attributes like buying price, maintenance cost, number of doors, person capacity, luggage boot size, and safety ratings.
#
# ### Objectives
#
# -   Enhanced Exploratory Data Analysis (EDA): To revisit and build upon our previous analysis, uncovering deeper insights into the categorical nature of the dataset. This includes visualizing the distribution of each attribute and understanding their interrelationships.
# -   Predictive Modeling and Clustering:
#     -   To deploy predictive models that answer key questions, such as which factors most significantly influence a car's safety rating.
#     -   To explore the feasibility of segmenting cars into distinct groups based on their attributes, potentially unveiling market segments within the automotive landscape.
#
# ### Methodology
#
# Our approach harnesses the power of machine learning, employing models suited to the categorical nature of our dataset. Utilizing cross-validation and scikit-learn pipelines, we aim to ensure robustness and reproducibility in our findings. This report presents a detailed analysis, from data preprocessing, model selection, training, to evaluation, culminating in insights that could guide both industry strategies and consumer choices.

# %% [markdown]
# # Exploratory Data Analysis (EDA) of Car Dataset
#
# We begin our analysis by performing an exploratory data analysis (EDA) on the `cars.csv` dataset. The EDA will provide us with an initial understanding of the dataset's characteristics, including the distribution of various features.

# %%
from src.Car_analysis.car_eda import CarDataEDA

#Initialize the EDA object
eda = CarDataEDA('cars.csv')

# Display dataset overview
eda.dataset_overview()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1728 entries, 0 to 1727
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   buying    1728 non-null   object
#  1   maint     1728 non-null   object
#  2   doors     1728 non-null   object
#  3   persons   1728 non-null   object
#  4   lug_boot  1728 non-null   object
#  5   safety    1728 non-null   object
#  6   class     1728 non-null   object
# dtypes: object(7)
# memory usage: 94.6+ KB
# None
#   buying  maint doors persons lug_boot safety  class
# 0  vhigh  vhigh     2       2    small    low  unacc
# 1  vhigh  vhigh     2       2    small    med  unacc
# 2  vhigh  vhigh     2       2    small   high  unacc
# 3  vhigh  vhigh     2       2      med    low  unacc
# 4  vhigh  vhigh     2       2      med    med  unacc

# %% [markdown]
# # Exploratory Data Analysis (EDA) of Car Dataset
#
# In this section, we perform an exploratory data analysis on the `cars.csv` dataset. We'll start with a basic overview, followed by visualizing the distribution of each feature and examining the correlations between them.

# %%
from src.Car_analysis.car_eda import CarDataEDA

# Initialize the EDA object
eda = CarDataEDA('cars.csv')

# Display dataset overview
eda.dataset_overview()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1728 entries, 0 to 1727
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   buying    1728 non-null   object
#  1   maint     1728 non-null   object
#  2   doors     1728 non-null   object
#  3   persons   1728 non-null   object
#  4   lug_boot  1728 non-null   object
#  5   safety    1728 non-null   object
#  6   class     1728 non-null   object
# dtypes: object(7)
# memory usage: 94.6+ KB
# None
#   buying  maint doors persons lug_boot safety  class
# 0  vhigh  vhigh     2       2    small    low  unacc
# 1  vhigh  vhigh     2       2    small    med  unacc
# 2  vhigh  vhigh     2       2    small   high  unacc
# 3  vhigh  vhigh     2       2      med    low  unacc
# 4  vhigh  vhigh     2       2      med    med  unacc

# %% [markdown]
# ### Dataset Overview
#
# The dataset comprises 1728 entries, each with 7 attributes related to car evaluations. All columns are of the object data type, indicating categorical data. Below is a snippet of the dataset, showing a range of features from 'buying' price to 'safety' ratings, culminating in the overall 'class' evaluation of the car:
#
# | buying | maint | doors | persons | lug_boot | safety | class |
# |--------|-------|-------|---------|----------|--------|-------|
# | vhigh  | vhigh | 2     | 2       | small    | low    | unacc |
# | vhigh  | vhigh | 2     | 2       | small    | med    | unacc |
# | vhigh  | vhigh | 2     | 2       | small    | high   | unacc |
# | vhigh  | vhigh | 2     | 2       | med      | low    | unacc |
# | vhigh  | vhigh | 2     | 2       | med      | med    | unacc |
#
# Each attribute contributes to the final assessment of a car's acceptability, ranging from unacceptable ('unacc') to acceptable and beyond. The absence of null values indicates a complete dataset, providing a solid foundation for further exploratory data analysis and predictive modeling.

# %% [markdown]
# ## Feature Distributions
#
# Next, let's visualize the distribution of each feature in the dataset to understand their frequency and diversity.

# %%
# Visualize distributions of each feature
eda.visualize_distributions()

# %% [markdown]
# ### Distribution of Car Classes
#
# This bar chart shows the frequency of different car classifications in our dataset. The 'unacc' class is the most frequent, which may suggest a tendency towards cars that are generally classified as unacceptable. This could be indicative of a stricter evaluation system or a dataset skewed towards lower-quality vehicles.
#
# ### Uniform Distribution of Maintenance Levels
#
# The last visualization highlights the distribution of different maintenance levels across the dataset. The relatively even distribution suggests that our dataset does not exhibit a bias towards any particular maintenance level, which is beneficial for building a predictive model that is not skewed by uneven data.

# %% [markdown]
# ## Correlation Analysis
#
# We will now perform a correlation analysis to uncover any interesting relationships between the different features of the dataset.

# %%
# Plot correlation heatmap
eda.plot_correlation_heatmap()

# %% [markdown]
# ### Correlation Heatmap for Categorical Data
#
# The heatmap provides a visual representation of the correlation between different categorical features of the cars. The closer the color is to red, the stronger the positive correlation, and the closer to blue, the stronger the negative correlation. Most variables show little to no correlation with each other, which could imply a high degree of independence among these features.

# %% [markdown]
# ## Maintenance Cost Distribution
#
# Let's start our analysis by examining how the maintenance costs are distributed across different cars in our dataset.

# %%
eda.visualize_maintenance_distribution()
# Out:
# c:\Users\Asus\Desktop\Bro\Firasath\Firasat\Project 3\src\my_package\car_eda.py:43: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=self.data["maint"], palette="Set2")

# %% [markdown]
# ### Distribution of Maintenance Costs
#
# The second chart presents the overall distribution of maintenance costs, irrespective of other factors. The uniform distribution across different maintenance cost levels indicates that each cost category is equally likely, highlighting the balanced nature of our dataset in terms of maintenance costs.

# %% [markdown]
# ## Feature Relationships with Maintenance Cost
#
# Understanding how various car attributes relate to maintenance costs can provide valuable insights. Here we explore these relationships.

# %%
eda.visualize_feature_relationships()

# %% [markdown]
# ### Relationship between Luggage Boot Size and Maintenance Cost
#
# The first visualization clearly demonstrates the distribution of maintenance costs across different sizes of the luggage boot. It's evident that for each boot size category, the maintenance cost tends to follow a similar distribution, suggesting that the luggage boot size does not significantly influence the maintenance cost.

# %% [markdown]
# ## Pairwise Relationships Analysis
#
# To get a broader understanding of our data, we'll look at the pairwise relationships between different features, including how they relate to maintenance costs.

# %%
eda.plot_pairwise_relationships()

# %% [markdown]
# The pairplot provides a comprehensive overview of the relationships between all pairs of features, displaying both distribution histograms and scatter plots. Each point on the scatter plots is colored by maintenance cost, which helps in visualizing patterns and correlations between different vehicle attributes.

# %% [markdown]
# ## Feature Importance Analysis
#
# Understanding which features most significantly influence the maintenance cost can provide key insights. Here, we use a Random Forest Classifier to determine feature importance.

# %%
eda.plot_feature_importances()

# %% [markdown]
# The bar chart titled "Feature Importance" ranks the features by their importance scores. The buying price appears to be the most influential feature, followed by the number of doors, lug_boot size, class, persons, and safety. The importance scores suggest the buying price has the most significant impact on the model's predictions.

# %% [markdown]
# ## Box Plots for Features Against Maintenance Cost
#
# Box plots can help visualize the distribution of different features against maintenance cost, providing a clear view of trends and outliers.

# %%
eda.plot_boxplots_against_maint()

# %% [markdown]
# The boxplot titled "buying vs Maintenance Cost" compares the encoded maintenance costs across different buying price categories: vhigh, high, med, and low. The boxplots show the spread and median of the encoded maintenance costs within each buying price category.

# %% [markdown]
# ## FacetGrid Analysis
#
# A FacetGrid allows us to explore complex relationships between multiple features. Here, we investigate how the features 'buying', 'persons', 'doors', and 'safety' interact with respect to maintenance cost.

# %%
eda.plot_facetgrid()

# %% [markdown]
# This matrix of scatter plots represents various combinations of car features against each other, such as doors, persons, and maintenance cost. Each subplot corresponds to a different combination of features, allowing for a pairwise comparison between the features.

# %% [markdown]
# ## Principal Component Analysis (PCA)
#
# PCA is used to reduce the dimensionality of our dataset while retaining the most important information. Here, we apply PCA to visualize our data in two dimensions.

# %%
eda.perform_pca_and_plot()

# %% [markdown]
# The scatter plot shows the principal component analysis (PCA) with two principal components on the x and y-axes, respectively. The color bar represents Maintenance Cost, ranging from low to high. The points are spread across the two principal components, showing a clear pattern that separates different maintenance costs across the principal components.

# %% [markdown]
# ## Stacked Bar Charts
#
# Stacked bar charts are helpful for visualizing the distribution of maintenance costs across different categories of various features.

# %%
eda.plot_stacked_bar_charts()

# %% [markdown]
# # Model Preparation
#
# ## Data Preprocessing and Train-Test Split
#
# Before we build the model, we need to preprocess our data. This includes one-hot encoding the categorical variables and splitting the data into training and test sets for model validation.

# %%
from src.Car_analysis.model import CarModel

# Initialize the model object
model = CarModel('cars.csv')

# Preprocess the data and split it into training and test sets
model.preprocess_and_split()

# %% [markdown]
# # Model Building and Evaluation
#
# ## Creating a Pipeline and Performing Cross-Validation
#
# In this step, we construct a pipeline that includes preprocessing with OneHotEncoder and a RandomForestClassifier. We then evaluate the model's performance using cross-validation.

# %%
# Building the model and performing cross-validation
model.build_and_evaluate_model()
# Out:
# Cross-validation scores: [0.68208092 0.73699422 0.74566474 0.83478261 0.8057971 ]
# Mean CV score: 0.7610639189075983

# %% [markdown]
# #### Model Building and Evaluation
#
# We built and evaluated our model using cross-validation to ensure its reliability and robustness. The cross-validation scores were consistently above 0.68, with a mean score of approximately 0.76, indicating a strong predictive capability of our model.

# %% [markdown]
# # Hyperparameter Tuning
#
# ## Using GridSearchCV to Optimize RandomForest Parameters
#
# To further enhance our model's performance, we will use GridSearchCV to search for the best hyperparameters for the RandomForestClassifier. This involves testing various combinations of parameters and evaluating them using cross-validation.

# %%
# Tuning the model's hyperparameters
model.tune_hyperparameters()
# Out:
# Best Parameters: {'classifier__max_depth': 10, 'classifier__min_samples_split': 2, 'classifier__n_estimators': 200}
# Best CV Score: 0.766272932897713

# %% [markdown]
# ## Hyperparameter Tuning
#
# To further refine our model, we conducted hyperparameter tuning, which yielded optimal parameters that enhanced the model's performance.

# %% [markdown]
# # Final Model Training and Evaluation
#
# After tuning the hyperparameters, we retrain our RandomForestClassifier with the best parameters found. We then evaluate the final model's performance on the test set using a confusion matrix and classification report.

# %%
# Perform hyperparameter tuning
model.tune_hyperparameters()

# Retrieve best parameters from hyperparameter tuning
best_parameters = model.get_best_parameters()

# Train and evaluate the final model using the best parameters
model.train_and_evaluate_final_model(best_parameters)
# Out:
# Best Parameters: {'classifier__max_depth': 10, 'classifier__min_samples_split': 2, 'classifier__n_estimators': 200}
# Best CV Score: 0.766272932897713
# Final Model Confusion Matrix:
#  [[ 3 21 19 32]
#  [24  5 41 28]
#  [25 29  1 25]
#  [52 11 13 17]]
#
# Final Model Classification Report:
#                precision    recall  f1-score   support
#
#         high       0.03      0.04      0.03        75
#          low       0.08      0.05      0.06        98
#          med       0.01      0.01      0.01        80
#        vhigh       0.17      0.18      0.17        93
#
#     accuracy                           0.08       346
#    macro avg       0.07      0.07      0.07       346
# weighted avg       0.08      0.08      0.07       346

# %% [markdown]
# ## Final Model Training and Evaluation
#
# Using the best parameters obtained from the tuning process, we trained our final model and evaluated it on the test data. The performance metrics of the final model are summarized below, highlighting the precision, recall, and F1-scores for each class.

# %% [markdown]
#     high       0.03      0.04      0.03        75
#      low       0.08      0.05      0.06        98
#      med       0.01      0.01      0.01        80
#    vhigh       0.17      0.18      0.17        93
#
# accuracy                           0.08       346

# %% [markdown]
# The confusion matrix and classification report provide a detailed insight into the areas where our model excels and where it could be improved. The model shows a relatively better performance for the 'vhigh' class, suggesting that it could be more sensitive to features that are indicative of this class.

# %% [markdown]
# # Data Preprocessing and Train-Test Split
#
# Before building the model, we need to preprocess our data, which includes one-hot encoding the categorical variables and splitting the dataset into training and test sets.

# %%
# Initialize the model object
model = CarModel('cars.csv')

# Preprocess the data and split it into training and test sets
model.preprocess_and_split()

# %% [markdown]
# # Model Building and Cross-Validation
#
# Next, we build a RandomForestClassifier model within a pipeline and evaluate its performance using cross-validation. This helps in understanding how well our model performs across different subsets of the dataset.

# %%
# Building the model and performing cross-validation
model.build_model_and_evaluate()
# Out:
# Cross-validation scores: [0.07581227 0.07220217 0.11594203 0.07971014 0.10507246]
# Mean CV score: 0.08974781562287448

# %% [markdown]
# ## Model Building and Cross-Validation
#
# The model was constructed and assessed through the process of cross-validation, which is critical for determining the model's efficacy and stability. The cross-validation scores ranged modestly, with a mean score of approximately 0.09, indicating room for improvement in the model's predictive performance.

# %% [markdown]
# # Hyperparameter Tuning with GridSearchCV
#
# To optimize our RandomForestClassifier model, we'll perform hyperparameter tuning using GridSearchCV. This process will find the best combination of parameters for our model.

# %%
# Tuning the model's hyperparameters
model.tune_hyperparameters()
# Out:
# Best Parameters: {'classifier__max_depth': 10, 'classifier__min_samples_split': 2, 'classifier__n_estimators': 200}
# Best CV Score: 0.766272932897713

# %% [markdown]
# ## Hyperparameter Tuning
#
# Hyperparameter tuning was employed to enhance the model's accuracy. The process resulted in identifying the best parameters, which significantly improved the cross-validation score to approximately 0.77, suggesting a substantial increase in the model's prediction accuracy.

# %% [markdown]
# # Final Model Evaluation
#
# After tuning the hyperparameters, we'll retrain the model on the entire training set and evaluate its performance on the test set using classification report and confusion matrix.

# %% [markdown]
# These steps in the modeling process are indicative of the iterative nature of model building, where initial results inform the subsequent tuning and refining of the model to achieve better accuracy and performance.

# %%
# First, tune the hyperparameters
model.tune_hyperparameters()

# Then, evaluate the final model with the best parameters
model.evaluate_final_model()

# %% [markdown]
# # One-Hot Encoding the Entire Dataset
#
# For our specific analysis, we'll apply one-hot encoding to the entire dataset. This transformation is useful for certain types of analyses where we need all features, including the target, in a one-hot encoded format.

# %%
# Applying one-hot encoding to the entire dataset
X_encoded_df = model.one_hot_encode_dataset()

# %% [markdown]
# # KMeans Clustering and the Elbow Method
#
# To explore potential clusters within our dataset, we'll apply KMeans clustering. The Elbow Method will be used to determine the optimal number of clusters by observing the within-cluster sum of squares (WCSS).

# %%
# Applying KMeans and using the Elbow Method to determine the optimal number of clusters
model.apply_kmeans_and_elbow_method(X_encoded_df)
# Out:
# c:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %% [markdown]
# # Applying KMeans Clustering
#
# Based on the Elbow Method, we will now apply KMeans clustering to our dataset with the identified optimal number of clusters. We will then analyze the characteristics of each cluster.

# %%
# Applying KMeans Clustering and analyzing the clusters
num_clusters = 4  # Adjust based on your Elbow plot observation
model.apply_kmeans_and_analyze_clusters(X_encoded_df, num_clusters)
# Out:
# Analysis of Cluster 0:
#        buying  maint doors persons lug_boot safety  class  Cluster
# count     357    357   357     357      357    357    357    357.0
# unique      4      4     4       3        3      1      1      NaN
# top     vhigh  vhigh     2       2    small    med  unacc      NaN
# freq      118    118   103     192      157    357    357      NaN
# mean      NaN    NaN   NaN     NaN      NaN    NaN    NaN      0.0
# std       NaN    NaN   NaN     NaN      NaN    NaN    NaN      0.0
# min       NaN    NaN   NaN     NaN      NaN    NaN    NaN      0.0
# 25%       NaN    NaN   NaN     NaN      NaN    NaN    NaN      0.0
# 50%       NaN    NaN   NaN     NaN      NaN    NaN    NaN      0.0
# 75%       NaN    NaN   NaN     NaN      NaN    NaN    NaN      0.0
# max       NaN    NaN   NaN     NaN      NaN    NaN    NaN      0.0
#
# Analysis of Cluster 1:
#        buying  maint doors persons lug_boot safety  class  Cluster
# ...

# %% [markdown]
# ### Conclusion for Project 4: Car Evaluation
#
# #### Data Preprocessing and Exploration
#
# The project commenced with meticulous data loading and preprocessing, where initial exploratory data analysis (EDA) revealed the dataset's structure and characteristics. All features were categorical, reflecting various aspects of car evaluation such as maintenance cost, safety, and capacity. The preprocessing phase included handling missing values, encoding categorical variables, and ensuring data quality for model ingestion. Notably, features like `lug_boot` and `safety` held potential predictive power as per our EDA insights.
#
# #### Model Building and Evaluation
#
# We embarked on model building with a clear understanding of our dataset. Cross-validation was a cornerstone of our model evaluation, ensuring that the model's performance was not just a fluke of a particular data split. Initial results were humble, with a mean cross-validation score that suggested the model required refinement.
#
# #### Hyperparameter Tuning
#
# The turning point was hyperparameter tuning, which significantly improved the model's accuracy. By tuning parameters such as `max_depth`, `min_samples_split`, and `n_estimators`, we enhanced the model's ability to generalize and captured the nuances in the data more effectively. The optimal parameters brought our cross-validation score up to approximately 0.77, a marked improvement from the initial score.
#
# #### Final Assessment
#
# In the final evaluation, the refined model displayed an appreciable performance, underpinned by the robustness introduced through cross-validation and tuning. The classification report and confusion matrix from the final model evaluation provided deeper insights into the model's strengths and areas for improvement, particularly in classifying different maintenance costs accurately.
#
# #### Insights and Future Work
#
# The project illuminated key relationships within the data, such as the link between `lug_boot` size and maintenance costs. It also highlighted the importance of safety and capacity in influencing car evaluations.
#
# Future work can expand on this foundation in several ways:
#
# -   Data Enrichment: Incorporating additional features, possibly continuous variables, could enrich the model's input and allow for more nuanced predictions.
# -   Algorithm Exploration: Experimenting with different modeling techniques, such as ensemble methods or neural networks, could uncover more complex patterns in the data.
# -   Feature Engineering: Creating new features from the existing ones might provide additional predictive power and improve model performance.
# -   Deployment and Monitoring: Deploying the model into a production environment and setting up a monitoring system would be a natural next step to operationalize the model's insights.
#
# In conclusion, the project underscored the iterative nature of machine learning projects, where each phase builds upon the previous and guides the subsequent one. The increase in the model's performance post-tuning demonstrated the potential of methodical parameter optimization. The insights gleaned have laid a solid foundation for predictive modeling in car evaluations, with clear pathways outlined for taking the project's achievements from the realms of academia to application.

# %% [markdown]
# ### References
#
# - "Hands-On Data Analysis with Pandas" by Stefanie Molin.
# - Seaborn Documentation: https://seaborn.pydata.org/
# - Scikit-Learn Documentation: https://scikit-learn.org/stable/
# - Pandas Documentation: https://pandas.pydata.org/pandas-docs/stable/
